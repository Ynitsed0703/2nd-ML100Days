# %% [markdown]
# # 作業 : (Kaggle)房價預測

# %% [markdown]
# # [作業目標]
# - 試著模仿範例寫法, 在房價預測中, 觀察去除離群值的影響

# %% [markdown]
# # [作業重點]
# - 觀察將極端值以上下限值取代, 對於分布與迴歸分數的影響 (In[5], Out[5])
# - 觀察將極端值資料直接刪除, 對於分布與迴歸分數的影響 (In[6], Out[6])

# %%
# 程式區塊 A：將需要的都import進來，設定好要使用的data路徑。
import os
import pandas            as pd
import numpy             as np
import seaborn           as sns
import matplotlib.pyplot as plt
import math
import warnings
from sklearn.preprocessing   import LabelEncoder, MinMaxScaler, StandardScaler
from sklearn.linear_model    import LogisticRegression,LinearRegression
from sklearn.model_selection import cross_val_score
MME = MinMaxScaler()
LR  = LogisticRegression()
LIR = LinearRegression()
warnings.filterwarnings('ignore')
# %matplotlib inline

# 設定【data的資料夾路徑】，命名為【data_folder】
data_folder = 'C:/Users/Ynitsed/Documents/GitHub/2nd-ML100Days/data'

# %%
# 設定t001為某個data路徑
# 設定t002為pd裡read data的功能
t001_train = os.path.join(data_folder, 'house_train.csv.gz')
t002_train = pd.read_csv(t001_train)
print('Path of read in data: %s' %t001_train)
print(t002_train.shape)
t002_train.head()
# Out:
# Path of read in data: C:/Users/Ynitsed/Documents/GitHub/2nd-ML100Days/data\house_train.csv.gz
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# ...

# %%
t002_train['1stFlrSF'].head(10)
# Out:
# 0     856
# 1    1262
# 2     920
# 3     961
# 4    1145
# 5     796
# 6    1694
# 7    1107
# 8    1022
# 9    1077
# Name: 1stFlrSF, dtype: int64

# %%
t002_train['SalePrice'].head(10)
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# 5    143000
# 6    307000
# 7    200000
# 8    129900
# 9    118000
# Name: SalePrice, dtype: int64

# %%
t003_train = np.log1p(t002_train['SalePrice'])
t003_train.head(10)
# 可以發現【SalePrice】取log1p後的狀況和上列不同
# Out:
# 0    12.247699
# 1    12.109016
# 2    12.317171
# 3    11.849405
# 4    12.429220
# 5    11.870607
# 6    12.634606
# 7    12.206078
# 8    11.774528
# 9    11.678448
# Name: SalePrice, dtype: float64

# %%
t004_train = t002_train.drop(['Id', 'SalePrice'] , axis=1)
t004_train.head(10)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
# 5          50       RL         85.0    14115   Pave   NaN      IR1
# 6          20       RL         75.0    10084   Pave   NaN      Reg
# 7          60       RL          NaN    10382   Pave   NaN      IR1
# 8          50       RM         51.0     6120   Pave   NaN      Reg
# 9         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# ...

# %%
#只取 int64, float64 兩種數值型欄位, 存於 num_features 中
num_features = []
for a, b in zip(t004_train.dtypes, t004_train.columns):
    if a == 'float64' or a == 'int64':
        num_features.append(b)
print(f'{len(num_features)} Numeric Features : {num_features}\n')
# Out:
# 36 Numeric Features : ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
# 只留數值型欄位
t005_train = t004_train[num_features]

# 把null填成-1
t006_train = t005_train.fillna(-1)
t006_train.head(10)
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
# 5          50         85.0    14115            5            5       1993
# 6          20         75.0    10084            8            5       2004
# 7          60         -1.0    10382            7            6       1973
# 8          50         51.0     6120            7            5       1931
# 9         190         50.0     7420            5            6       1939
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# 0          2003       196.0         706           0  ...         548
# ...

# %%
# 把train的筆數算出來
train_cnt = t003_train.shape[0]
train_cnt
# Out:
# 1460

# %% [markdown]
# # 作業1
# * 試著限制 '1樓地板面積(平方英尺)' (1stFlrSF) 欄位的上下限, 看看能否再進一步提高分數?

# %%
# 一對一的線性觀察
sns.regplot(x = t006_train['1stFlrSF'][:train_cnt], y=t003_train)
plt.show()

# %%
# 做線性迴歸, 觀察分數
t007_train = MME.fit_transform(t006_train)
cross_val_score(LIR, t007_train, t003_train, cv=5).mean()
# Out:
# 0.8499683837163878

# %%
# 將 1stFlrSF 限制在 500 到 2000 以內, 去除極端值
# 教材這樣講其實很不清楚，去除？所以極端值被我刪掉了嗎？並沒有！
# 是把極端值以500或2000取代，比500小的當作500，比2000大的當作2000
# 原來有clip這個函數，這樣就不必用改的了。
t006_train['1stFlrSF'] = t006_train['1stFlrSF'].clip(500, 2000)
sns.regplot(x = t006_train['1stFlrSF'][:train_cnt], y=t003_train)
plt.show()
print(t006_train.shape)
# Out:
# (1460, 36)

# %%
# 做線性迴歸, 觀察分數
t007_train = MME.fit_transform(t006_train)
cross_val_score(LIR, t007_train, t003_train, cv=5).mean()
# Out:
# 0.876580486010791

# %% [markdown]
# # 作業2
# * 續前題, 去除離群值有兩類方式 :  捨棄離群值(刪除離群的資料) 以及調整離群值,
# 請試著用同樣的上下限, 改為 '捨棄離群值' 的方法, 看看結果會變好還是變差? 並試著解釋原因。

# %%
# 將 1stFlrSF 限制在 500 到 2000 以內, 捨棄離群值
# 這個才真的是把極端值刪掉
filter = (t006_train['1stFlrSF']> 500) & (t006_train['1stFlrSF']< 2000)
t006_train = t006_train[filter]
t003_train = t003_train[filter]
sns.regplot(x = t006_train['1stFlrSF'], y=t003_train)
plt.show()
print(t006_train.shape) #可發現排掉了54個，原本有1460個。
# Out:
# (1406, 36)

# %%
# 做線性迴歸, 觀察分數
t007_train = MME.fit_transform(t006_train)
cross_val_score(LIR, t007_train, t003_train, cv=5).mean()
# Out:
# 0.8854993000354359

# %%
# 做線性迴歸, 觀察分數
# 看看直接使用取log前的分數如何？果然比較低，取log有用！
t007_train = MME.fit_transform(t006_train)
cross_val_score(LIR, t007_train, t002_train['SalePrice'][filter], cv=5).mean()
# Out:
# 0.8518320541724105

# %%
# 做線性迴歸, 觀察分數
# 用羅吉斯看看......超低!!!
t007_train = MME.fit_transform(t006_train)
cross_val_score(LR, t007_train, t002_train['SalePrice'][filter], cv=5).mean()
# Out:
# 0.020193209089760814

# %% [markdown]
# ### Day20教材方向和目標
# 1. sns.regplot(x=,y=)
# 2. np.log1p          :取log可以降低極端值的影響
# 3. np.clip(min,max)  :直接把極端值用最小值最大值限制住
#
# ### Day20忽略部分
# 1. cross_val_score的其他參數
#
# ### Day20其他補充
# 今天教材也不錯。
# 只是統計觀念上的內容，很難在這樣的教材釐清，為什麼是取【>500和<2000】，
# 希望之後的教材可以教到用其他方式替代值皆人工訂定的方法。
